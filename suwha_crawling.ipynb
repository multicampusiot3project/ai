# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.select import Select
from time    import sleep, time



# crawling
from bs4 import BeautifulSoup

from urllib.request import urlopen, urlretrieve
from urllib.error   import HTTPError
from urllib.error   import URLError

# %%
# 창띄우기
path = '../driver/chromedriver.exe'
driver = webdriver.Chrome(path)
#driver.get('https://www.ildong.com/kor/product/list.id?page=0&halt=&prdDisease=&prdCategory=&searchVal=&searchOption=0
# driver.get('https://sldict.korean.go.kr/front/sign/signList.do?top_category=CTE')
# Out:
# C:\Users\yourm\AppData\Local\Temp/ipykernel_484/3805595081.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)

# %%
count = 0
for i in range(1, 381, 1): # 총 381 페이지
    driver.get(f'https://sldict.korean.go.kr/front/sign/signList.do;sldictserv=jWf0falReQUugRC0GCj_oxXFgRR4nmf6nPmVU3MVYpGVqG-jXNcL!-1705233038?current_pos_index=&origin_no=0&searchWay=&top_category=CTE&category=&detailCategory=&searchKeyword=&pageIndex={i}&pageJumpIndex=')
    # li_list = driver.find_elements_by_css_selector('.wrap_list > ul > li > .list_right > .lst > list > li > div > p > .tit > a')
    li_list = driver.find_elements_by_css_selector('.wrap_list > ul > li ')
    print(len(li_list))
    
    for li in li_list:
        print(count)
        a = li.find_element_by_css_selector('.list_right > .lst > #list > li > div > p > .tit > a')
        count_srt = f'{count}'
        print(count_srt)
        count_srt = count_srt.zfill(4) # 없으면 0으로 채우는 4자리 숫자 만들기

        name = count_srt + '_' + a.text
        print(a.text)
        print(a.get_attribute('href'))
        a.click()
        sleep(3)

        select_element = driver.find_element(By.ID,'viewSelect')
        select_object = Select(select_element)
        select_object.select_by_value('row')
        sleep(2)
        video_src = driver.find_elements_by_css_selector('#videoArea > #html5Video > source')[1]

        print(video_src.get_attribute('src'))
        import os
        img_folder = './suwha'
        if not os.path.isdir(img_folder):
            os.mkdir(img_folder)
        file_name = f'{img_folder}/{name}.mp4'
        print(file_name)
        urlretrieve(video_src.get_attribute('src') , file_name)
        driver.back()
        sleep(1)

        count += 1
# Out:
# C:\Users\yourm\AppData\Local\Temp/ipykernel_484/2397500064.py:5: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   li_list = driver.find_elements_by_css_selector('.wrap_list > ul > li ')
# 10
# 0
# 0
# 뻐기다
# javascript:fnSearchContentsView('10127', '0');
# C:\Users\yourm\AppData\Local\Temp/ipykernel_484/2397500064.py:25: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   video_src = driver.find_elements_by_css_selector('#videoArea > #html5Video > source')[1]
# http://sldict.korean.go.kr/multimedia/multimedia_files/convert/20151225/234456/MOV000245500_320X240.mp4
# ./suwha/0000_뻐기다.mp4
# 1
# 1
# 답
# javascript:fnSearchContentsView('23933', '1');
# http://sldict.korean.go.kr/multimedia/multimedia_files/convert/20200901/739060/MOV000251190_320X240.mp4
# ./suwha/0001_답.mp4
# 2
# 2
# 그냥,그저
# javascript:fnSearchContentsView('23922', '2');
# ...
